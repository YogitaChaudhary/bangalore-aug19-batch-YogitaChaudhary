# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ##Read the data set and replace dashes with 0 to make sure you can perform arithmetic operations on the data

# %%
laliga = pd.read_csv('laliga.csv',names=['Pos','Team','Seasons','Points','GamesPlayed','GamesWon','GamesDrawn','GamesLost','GoalsFor','GoalsAgainst','Champion','Runner0up','Third','Fourth','Fifth','Sixth','T','Debut','Since/LastApp','BestPosition'])

# %%
laliga
# Out:
#     Pos                 Team  Seasons  Points  GamesPlayed  GamesWon  \
# 0   NaN                  NaN      NaN     NaN          NaN       NaN
# 1   Pos                 Team  Seasons  Points  GamesPlayed  GamesWon
# 2     1          Real Madrid       86    4385         2762      1647
# 3     2            Barcelona       86    4262         2762      1581
# 4     3      Atletico Madrid       80    3442         2614      1241
# 5     4             Valencia       82    3386         2664      1187
# 6     5      Athletic Bilbao       86    3368         2762      1209
# 7     6              Sevilla       73    2819         2408       990
# 8     7             Espanyol       82    2792         2626       948
# 9     8        Real Sociedad       70    2573         2302       864
# 10    9             Zaragoza       58    2109         1986       698
# 11   10           Real Betis       51    1884         1728       606
# 12   11  Deportivo La Coruna       45    1814         1530       563
# ...

# %%
laliga1=laliga.drop(laliga.index[[0,1]])
laliga1
# Out:
#    Pos                 Team Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 2    1          Real Madrid      86   4385        2762     1647        552
# 3    2            Barcelona      86   4262        2762     1581        573
# 4    3      Atletico Madrid      80   3442        2614     1241        598
# 5    4             Valencia      82   3386        2664     1187        616
# 6    5      Athletic Bilbao      86   3368        2762     1209        633
# 7    6              Sevilla      73   2819        2408      990        531
# 8    7             Espanyol      82   2792        2626      948        608
# 9    8        Real Sociedad      70   2573        2302      864        577
# 10   9             Zaragoza      58   2109        1986      698        522
# 11  10           Real Betis      51   1884        1728      606        440
# 12  11  Deportivo La Coruna      45   1814        1530      563        392
# ...

# %%
laliga1 = laliga1.replace('-',0)
laliga1
# Out:
#    Pos                 Team Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 2    1          Real Madrid      86   4385        2762     1647        552
# 3    2            Barcelona      86   4262        2762     1581        573
# 4    3      Atletico Madrid      80   3442        2614     1241        598
# 5    4             Valencia      82   3386        2664     1187        616
# 6    5      Athletic Bilbao      86   3368        2762     1209        633
# 7    6              Sevilla      73   2819        2408      990        531
# 8    7             Espanyol      82   2792        2626      948        608
# 9    8        Real Sociedad      70   2573        2302      864        577
# 10   9             Zaragoza      58   2109        1986      698        522
# 11  10           Real Betis      51   1884        1728      606        440
# 12  11  Deportivo La Coruna      45   1814        1530      563        392
# ...

# %%
laliga1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 61 entries, 2 to 62
# Data columns (total 20 columns):
# Pos              61 non-null object
# Team             61 non-null object
# Seasons          61 non-null object
# Points           61 non-null object
# GamesPlayed      61 non-null object
# GamesWon         61 non-null object
# GamesDrawn       61 non-null object
# GamesLost        61 non-null object
# GoalsFor         61 non-null object
# GoalsAgainst     61 non-null object
# Champion         61 non-null object
# Runner0up        61 non-null object
# Third            61 non-null object
# Fourth           61 non-null object
# Fifth            61 non-null object
# Sixth            61 non-null object
# T                61 non-null object
# Debut            61 non-null object
# Since/LastApp    61 non-null object
# BestPosition     61 non-null object
# dtypes: object(20)
# memory usage: 10.0+ KB

# %%
names={'Pos':int,'Seasons':int,'Points':int,'GamesPlayed':int,'GamesWon':int,'GamesDrawn':int,'GamesLost':int,'GoalsFor':int,'GoalsAgainst':int,'Champion':int,'Runner0up':int,'Third':int,'Fourth':int,'Fifth':int,'Sixth':int,'T':int,}
laliga1 = laliga1.astype(names)

# %%
laliga1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 61 entries, 2 to 62
# Data columns (total 20 columns):
# Pos              61 non-null int32
# Team             61 non-null object
# Seasons          61 non-null int32
# Points           61 non-null int32
# GamesPlayed      61 non-null int32
# GamesWon         61 non-null int32
# GamesDrawn       61 non-null int32
# GamesLost        61 non-null int32
# GoalsFor         61 non-null int32
# GoalsAgainst     61 non-null int32
# Champion         61 non-null int32
# Runner0up        61 non-null int32
# Third            61 non-null int32
# Fourth           61 non-null int32
# Fifth            61 non-null int32
# Sixth            61 non-null int32
# T                61 non-null int32
# Debut            61 non-null object
# Since/LastApp    61 non-null object
# BestPosition     61 non-null object
# dtypes: int32(16), object(4)
# memory usage: 6.2+ KB

# %%
##Print all the teams which have started playing between 1930-1980

# %%
print(laliga1[(laliga1.Debut > '1930') & (laliga1.Debut < '1980')][['Team','Debut']])
# Out:
#                    Team    Debut
# 5              Valencia  1931-32
# 7               Sevilla  1934-35
# 10             Zaragoza  1939-40
# 11           Real Betis  1932-33
# 12  Deportivo La Coruna  1941-42
# 13           Celta Vigo  1939-40
# 14           Valladolid  1948-49
# 16       Sporting Gijon  1944-45
# 17              Osasuna  1935-36
# 18               Malaga  1949-50
# 19               Oviedo  1933-34
# 20             Mallorca  1960-61
# 21           Las Palmas  1951-52
# 23              Granada  1941-42
# 24       Rayo Vallecano  1977-78
# 25                Elche  1959-60
# 27             Hercules  1935-36
# 28             Tenerife  1961-62
# 29               Murcia  1940-41
# 30               Alaves  1930-31
# 31              Levante  1963-64
# 32            Salamanca  1974-75
# 33             Sabadell  1943-44
# 34                Cadiz  1977-78
# 36            Castellon  1941-42
# 39              Cordoba  1962-63
# 41           Recreativo  1978-79
# ...

# %%
##Print the list of teams which came Top 5 in terms of points

# %%
laliga1.sort_values("Points",ascending = False).head(5)
# Out:
#    Pos             Team  Seasons  Points  GamesPlayed  GamesWon  GamesDrawn  \
# 2    1      Real Madrid       86    4385         2762      1647         552
# 3    2        Barcelona       86    4262         2762      1581         573
# 4    3  Atletico Madrid       80    3442         2614      1241         598
# 5    4         Valencia       82    3386         2664      1187         616
# 6    5  Athletic Bilbao       86    3368         2762      1209         633
#
#    GamesLost  GoalsFor  GoalsAgainst  Champion  Runner0up  Third  Fourth  \
# 2        563      5947          3140        33         23      8       8
# 3        608      5900          3114        25         25     12      12
# 4        775      4534          3309        10          8     16       9
# 5        861      4398          3469         6          6     10      11
# 6        920      4631          3700         8          7     10       5
#
#    Fifth  Sixth   T    Debut Since/LastApp BestPosition
# ...

# %%
## Write a function with name “Goal_diff_count” which should return all the teams with their Goal Differences. Using the same function, find the team which has maximum and minimum goal difference. (5 points)
## Goal_diff_count = GoalsFor - GoalsAgainst

# %%
laliga2 =laliga1.set_index('Team')
laliga2
laliga1['Goal_Difference'] = laliga1['GoalsFor'] - laliga1['GoalsAgainst'] 
laliga1
# Out:
#     Pos                 Team  Seasons  Points  GamesPlayed  GamesWon  \
# 2     1          Real Madrid       86    4385         2762      1647
# 3     2            Barcelona       86    4262         2762      1581
# 4     3      Atletico Madrid       80    3442         2614      1241
# 5     4             Valencia       82    3386         2664      1187
# 6     5      Athletic Bilbao       86    3368         2762      1209
# 7     6              Sevilla       73    2819         2408       990
# 8     7             Espanyol       82    2792         2626       948
# 9     8        Real Sociedad       70    2573         2302       864
# 10    9             Zaragoza       58    2109         1986       698
# 11   10           Real Betis       51    1884         1728       606
# 12   11  Deportivo La Coruna       45    1814         1530       563
# 13   12           Celta Vigo       51    1789         1698       586
# 14   13           Valladolid       42    1471         1466       463
# ...

# %%
max_goal = laliga1['Goal_Difference'].max()
min_goal = laliga1['Goal_Difference'].min()
print("max_goal is",max_goal)
print("min_goal is",min_goal)
# Out:
# max_goal is 2807
# min_goal is -525

# %%
##Create a new column with name “Winning Percent” and append it to the data set

# %%
laliga2 = laliga1.sort_values("Points",ascending = False).head(5)
laliga1['Winning_Percentage'] = (laliga1['GamesWon'] / laliga1['GamesPlayed'])*100 
laliga2
# Out:
#    Pos             Team  Seasons  Points  GamesPlayed  GamesWon  GamesDrawn  \
# 2    1      Real Madrid       86    4385         2762      1647         552
# 3    2        Barcelona       86    4262         2762      1581         573
# 4    3  Atletico Madrid       80    3442         2614      1241         598
# 5    4         Valencia       82    3386         2664      1187         616
# 6    5  Athletic Bilbao       86    3368         2762      1209         633
#
#    GamesLost  GoalsFor  GoalsAgainst  ...  Third  Fourth  Fifth  Sixth   T  \
# 2        563      5947          3140  ...      8       8      3      4  79
# 3        608      5900          3114  ...     12      12      4      6  83
# 4        775      4534          3309  ...     16       9      7      6  56
# 5        861      4398          3469  ...     10      11     10      7  50
# 6        920      4631          3700  ...     10       5      8     10  49
#
# ...

# %%
##Group teams based on their “Best position” and print the sum of their points for all positions

# %%
df = laliga1.groupby('BestPosition')
print(df['Points'].sum())
# Out:
# BestPosition
# 1     27933
# 10      450
# 11      445
# 12      511
# 14       71
# 15       14
# 16       81
# 17      266
# 19       81
# 2      6904
# 20       34
# 3      5221
# 4      6563
# 5      1884
# 6      2113
# 7      1186
# 8      1134
# 9        96
# Name: Points, dtype: int32
