# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- ------------------
# -                                  nsorflow-estimator
# -.nsorboard                        2.1.0
# -ensorboard                        2.1.0
# -ensorflow-estimator               2.1.0
# -nsorboard                         2.1.0
# -nsorflow-estimator                2.1.0
# absl-py                            0.9.0
# alabaster                          0.7.12
# anaconda-client                    1.7.2
# anaconda-navigator                 1.9.7
# anaconda-project                   0.8.3
# arviz                              0.6.1
# asgiref                            3.2.3
# asn1crypto                         0.24.0
# astor                              0.8.1
# astroid                            2.2.5
# astropy                            3.2.1
# atomicwrites                       1.3.0
# attrs                              19.1.0
# autoimpute                         0.11.6
# Babel                              2.7.0
# backcall                           0.1.0
# backports.functools-lru-cache      1.5
# backports.os                       0.1.1
# backports.shutil-get-terminal-size 1.0.0
# backports.tempfile                 1.0
# backports.weakref                  1.0.post1
# beautifulsoup4                     4.7.1
# bitarray                           0.9.3
# bkcharts                           0.2
# bleach                             3.1.0
# bokeh                              1.2.0
# boto                               2.49.0
# Bottleneck                         1.2.1
# cachetools                         4.0.0
# certifi                            2019.11.28
# cffi                               1.12.3
# cftime                             1.0.4.2
# chardet                            3.0.4
# Click                              7.0
# cloudpickle                        1.2.1
# clyent                             1.2.2
# colorama                           0.4.1
# comtypes                           1.1.7
# conda                              4.8.1
# conda-build                        3.18.8
# conda-package-handling             1.3.11
# conda-verify                       3.4.2
# contextlib2                        0.5.5
# cryptography                       2.7
# cycler                             0.10.0
# Cython                             0.29.12
# cytoolz                            0.10.0
# dask                               2.1.0
# decorator                          4.4.0
# defusedxml                         0.6.0
# distributed                        2.1.0
# Django                             3.0.2
# django-model-utils                 4.0.0
# docutils                           0.14
# eli5                               0.10.1
# entrypoints                        0.3
# et-xmlfile                         1.0.1
# fastcache                          1.1.0
# filelock                           3.0.12
# Flask                              1.1.1
# future                             0.17.1
# gast                               0.2.2
# gevent                             1.4.0
# glob2                              0.7
# google-auth                        1.11.0
# google-auth-oauthlib               0.4.1
# google-pasta                       0.1.8
# graphviz                           0.13.2
# greenlet                           0.4.15
# grpcio                             1.26.0
# h5py                               2.9.0
# heapdict                           1.0.0
# html5lib                           1.0.1
# idna                               2.8
# imageio                            2.5.0
# imagesize                          1.1.0
# importlib-metadata                 0.17
# impyute                            0.0.8
# ipykernel                          5.1.1
# ipython                            7.6.1
# ipython-genutils                   0.2.0
# ipywidgets                         7.5.0
# isort                              4.3.21
# itsdangerous                       1.1.0
# jdcal                              1.4.1
# jedi                               0.13.3
# Jinja2                             2.10.1
# joblib                             0.13.2
# json5                              0.8.4
# jsonschema                         3.0.1
# jupyter                            1.0.0
# jupyter-client                     5.3.1
# jupyter-console                    6.0.0
# jupyter-core                       4.5.0
# jupyterlab                         1.0.2
# jupyterlab-server                  1.0.0
# Keras                              2.3.1
# Keras-Applications                 1.0.8
# Keras-Preprocessing                1.1.0
# keyring                            18.0.0
# kiwisolver                         1.1.0
# knnimpute                          0.1.0
# lazy-object-proxy                  1.4.1
# libarchive-c                       2.8
# lime                               0.1.1.37
# llvmlite                           0.29.0
# locket                             0.2.0
# lxml                               4.3.4
# Markdown                           3.1.1
# MarkupSafe                         1.1.1
# matplotlib                         3.1.0
# mccabe                             0.6.1
# menuinst                           1.4.16
# missingno                          0.4.2
# mistune                            0.8.4
# mkl-fft                            1.0.12
# mkl-random                         1.0.2
# mkl-service                        2.0.2
# mlxtend                            0.17.0
# mock                               3.0.5
# more-itertools                     7.0.0
# mpmath                             1.1.0
# msgpack                            0.6.1
# multipledispatch                   0.6.0
# navigator-updater                  0.2.1
# nbconvert                          5.5.0
# nbformat                           4.4.0
# netCDF4                            1.5.3
# networkx                           2.3
# nltk                               3.4.4
# nose                               1.3.7
# notebook                           6.0.0
# numba                              0.44.1
# numexpr                            2.6.9
# numpy                              1.16.4
# numpydoc                           0.9.1
# oauthlib                           3.1.0
# olefile                            0.46
# openpyxl                           2.6.2
# opt-einsum                         3.1.0
# osqp                               0.6.1
# packaging                          19.0
# pandas                             0.24.2
# pandas-profiling                   1.4.1
# pandocfilters                      1.4.2
# parso                              0.5.0
# partd                              1.0.0
# path.py                            12.0.1
# pathlib2                           2.3.4
# patsy                              0.5.1
# pep8                               1.7.1
# pickleshare                        0.7.5
# Pillow                             6.1.0
# pip                                19.1.1
# pkginfo                            1.5.0.1
# pluggy                             0.12.0
# ply                                3.11
# progressbar                        2.5
# prometheus-client                  0.7.1
# prompt-toolkit                     2.0.9
# protobuf                           3.11.2
# psutil                             5.6.3
# py                                 1.8.0
# pyasn1                             0.4.8
# pyasn1-modules                     0.2.8
# pycodestyle                        2.5.0
# pycosat                            0.6.3
# pycparser                          2.19
# pycrypto                           2.6.1
# pycurl                             7.43.0.3
# pyflakes                           2.1.1
# Pygments                           2.4.2
# pylint                             2.3.1
# pymc3                              3.8
# pyodbc                             4.0.26
# pyOpenSSL                          19.0.0
# pyparsing                          2.4.0
# pyreadline                         2.1
# pyrsistent                         0.14.11
# PySocks                            1.7.0
# pytest                             5.0.1
# pytest-arraydiff                   0.3
# pytest-astropy                     0.5.0
# pytest-doctestplus                 0.3.0
# pytest-openfiles                   0.3.2
# pytest-remotedata                  0.3.1
# python-dateutil                    2.8.0
# python-utils                       2.3.0
# pytz                               2019.1
# PyWavelets                         1.0.3
# pywin32                            223
# pywinpty                           0.5.5
# PyYAML                             5.1.1
# pyzmq                              18.0.0
# QtAwesome                          0.5.7
# qtconsole                          4.5.1
# QtPy                               1.8.0
# rake-nltk                          1.0.4
# requests                           2.22.0
# requests-oauthlib                  1.3.0
# rope                               0.14.0
# rsa                                4.0
# ruamel-yaml                        0.15.46
# scikit-image                       0.15.0
# scikit-learn                       0.21.2
# scikit-surprise                    1.1.0
# scipy                              1.3.2
# seaborn                            0.9.0
# Send2Trash                         1.5.0
# setuptools                         41.0.1
# shap                               0.34.0
# simplegeneric                      0.8.1
# singledispatch                     3.4.0.3
# six                                1.12.0
# sklearn-evaluation                 0.5
# snowballstemmer                    1.9.0
# sortedcollections                  1.1.2
# sortedcontainers                   2.1.0
# soupsieve                          1.8
# Sphinx                             2.1.2
# sphinxcontrib-applehelp            1.0.1
# sphinxcontrib-devhelp              1.0.1
# sphinxcontrib-htmlhelp             1.0.2
# sphinxcontrib-jsmath               1.0.1
# sphinxcontrib-qthelp               1.0.2
# sphinxcontrib-serializinghtml      1.1.3
# sphinxcontrib-websupport           1.1.2
# spyder                             3.3.6
# spyder-kernels                     0.5.1
# SQLAlchemy                         1.3.5
# sqlparse                           0.3.0
# statsmodels                        0.10.0
# sympy                              1.4
# tables                             3.5.2
# tabulate                           0.8.6
# tblib                              1.4.0
# tensorboard                        2.0.2
# tensorflow                         2.0.0
# tensorflow-estimator               2.0.1
# termcolor                          1.1.0
# terminado                          0.8.2
# testpath                           0.4.2
# Theano                             1.0.4
# toolz                              0.10.0
# tornado                            6.0.3
# tqdm                               4.32.1
# traitlets                          4.3.2
# unicodecsv                         0.14.1
# urllib3                            1.24.2
# wcwidth                            0.1.7
# webencodings                       0.5.1
# Werkzeug                           0.15.4
# wheel                              0.33.4
# widgetsnbextension                 3.5.0
# win-inet-pton                      1.1.0
# win-unicode-console                0.5
# wincertstore                       0.2
# wrapt                              1.11.2
# xarray                             0.14.1
# xgboost                            0.90
# xlrd                               1.2.0
# XlsxWriter                         1.1.8
# xlwings                            0.15.8
# xlwt                               1.3.0
# zict                               1.0.0
# zipp                               0.5.1

# %%
# !pip install -U tensorflow==2.0
# Out:
# Requirement already up-to-date: tensorflow==2.0 in c:\programdata\anaconda3\lib\site-packages (2.0.0)
# Requirement already satisfied, skipping upgrade: opt-einsum>=2.3.2 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==2.0) (3.1.0)
# Requirement already satisfied, skipping upgrade: numpy<2.0,>=1.16.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==2.0) (1.16.4)
# Requirement already satisfied, skipping upgrade: tensorboard<2.1.0,>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==2.0) (2.0.2)
# Requirement already satisfied, skipping upgrade: astor>=0.6.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==2.0) (0.8.1)
# Requirement already satisfied, skipping upgrade: wheel>=0.26 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==2.0) (0.33.4)
# Requirement already satisfied, skipping upgrade: google-pasta>=0.1.6 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==2.0) (0.1.8)
# Requirement already satisfied, skipping upgrade: keras-applications>=1.0.8 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==2.0) (1.0.8)
# Requirement already satisfied, skipping upgrade: grpcio>=1.8.6 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==2.0) (1.26.0)
# Requirement already satisfied, skipping upgrade: wrapt>=1.11.1 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==2.0) (1.11.2)
# Requirement already satisfied, skipping upgrade: keras-preprocessing>=1.0.5 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==2.0) (1.1.0)
# Requirement already satisfied, skipping upgrade: termcolor>=1.1.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==2.0) (1.1.0)
# Requirement already satisfied, skipping upgrade: absl-py>=0.7.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==2.0) (0.9.0)
# Requirement already satisfied, skipping upgrade: tensorflow-estimator<2.1.0,>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==2.0) (2.0.1)
# Requirement already satisfied, skipping upgrade: gast==0.2.2 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==2.0) (0.2.2)
# Requirement already satisfied, skipping upgrade: protobuf>=3.6.1 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==2.0) (3.11.2)
# Requirement already satisfied, skipping upgrade: six>=1.10.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow==2.0) (1.12.0)
# Requirement already satisfied, skipping upgrade: werkzeug>=0.11.15 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow==2.0) (0.15.4)
# Requirement already satisfied, skipping upgrade: markdown>=2.6.8 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow==2.0) (3.1.1)
# Requirement already satisfied, skipping upgrade: google-auth-oauthlib<0.5,>=0.4.1 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow==2.0) (0.4.1)
# Requirement already satisfied, skipping upgrade: google-auth<2,>=1.6.3 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow==2.0) (1.11.0)
# Requirement already satisfied, skipping upgrade: requests<3,>=2.21.0 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow==2.0) (2.22.0)
# Requirement already satisfied, skipping upgrade: setuptools>=41.0.0 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow==2.0) (41.0.1)
# Requirement already satisfied, skipping upgrade: h5py in c:\programdata\anaconda3\lib\site-packages (from keras-applications>=1.0.8->tensorflow==2.0) (2.9.0)
# Requirement already satisfied, skipping upgrade: requests-oauthlib>=0.7.0 in c:\programdata\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0) (1.3.0)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in c:\programdata\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0) (0.2.8)
# Requirement already satisfied, skipping upgrade: cachetools<5.0,>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0) (4.0.0)
# Requirement already satisfied, skipping upgrade: rsa<4.1,>=3.1.4 in c:\programdata\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0) (4.0)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0) (2019.11.28)
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0) (2.8)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0) (1.24.2)
# Requirement already satisfied, skipping upgrade: oauthlib>=3.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0) (3.1.0)
# Requirement already satisfied, skipping upgrade: pyasn1<0.5.0,>=0.4.6 in c:\programdata\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0) (0.4.8)

# %%
import tensorflow as tf    # importing tensorflow libraries

# %%
tf.__version__
# Out:
# '2.0.0'

# %%
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers.core import Dense,Dropout,Activation,Flatten
#from keras.layers.convolutional import Conv2D,MaxPooling2D
from keras.utils import np_utils
from sklearn import metrics
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
bank_df = pd.read_csv('bank.csv')

# %%
bank_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
# RowNumber          10000 non-null int64
# CustomerId         10000 non-null int64
# Surname            10000 non-null object
# CreditScore        10000 non-null int64
# Geography          10000 non-null object
# Gender             10000 non-null object
# Age                10000 non-null int64
# Tenure             10000 non-null int64
# Balance            10000 non-null float64
# NumOfProducts      10000 non-null int64
# HasCrCard          10000 non-null int64
# IsActiveMember     10000 non-null int64
# EstimatedSalary    10000 non-null float64
# Exited             10000 non-null int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
bank_df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
bank_df.shape
# Out:
# (10000, 14)

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
#include relevant columns within x and y
X = bank_df.iloc[:, 3:13]
y = bank_df.iloc[:, 13]

# %%
X.shape
# Out:
# (10000, 10)

# %%
y.shape
# Out:
# (10000,)

# %%
X[:].head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 0          1               1        101348.88
# 1          0               1        112542.58
# 2          1               0        113931.57
# 3          0               0         93826.63
# 4          1               1         79084.10

# %%
y[:].head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    0
# Name: Exited, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %%
labelencoder_x = LabelEncoder()
X.iloc[:, 1] = labelencoder_x.fit_transform(X.iloc[:, 1]) #applying on Geography
X.head()
# Out:
#    CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619          0  Female   42       2       0.00              1
# 1          608          2  Female   41       1   83807.86              1
# 2          502          0  Female   42       8  159660.80              3
# 3          699          0  Female   39       1       0.00              2
# 4          850          2  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 0          1               1        101348.88
# 1          0               1        112542.58
# 2          1               0        113931.57
# 3          0               0         93826.63
# 4          1               1         79084.10

# %%
labelencoder_x_2 = LabelEncoder()
X.iloc[:, 2] = labelencoder_x_2.fit_transform(X.iloc[:, 2]) #applying on Gender
X.head()
# Out:
#    CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619          0       0   42       2       0.00              1
# 1          608          2       0   41       1   83807.86              1
# 2          502          0       0   42       8  159660.80              3
# 3          699          0       0   39       1       0.00              2
# 4          850          2       0   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 0          1               1        101348.88
# 1          0               1        112542.58
# 2          1               0        113931.57
# 3          0               0         93826.63
# 4          1               1         79084.10

# %%
from keras.utils import to_categorical
encoded = pd.DataFrame(to_categorical(X.iloc[:, 1]))
#no need to encode Gender, as there are only two categories

X = pd.concat([encoded, X], axis = 1)
X.head()
# Out:
#      0    1    2  CreditScore  Geography  Gender  Age  Tenure    Balance  \
# 0  1.0  0.0  0.0          619          0       0   42       2       0.00
# 1  0.0  0.0  1.0          608          2       0   41       1   83807.86
# 2  1.0  0.0  0.0          502          0       0   42       8  159660.80
# 3  1.0  0.0  0.0          699          0       0   39       1       0.00
# 4  0.0  0.0  1.0          850          2       0   43       2  125510.82
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# 0              1          1               1        101348.88
# 1              1          0               1        112542.58
# 2              3          1               0        113931.57
# 3              2          0               0         93826.63
# 4              1          1               1         79084.10

# %%
#Dropping the existing "geography" category, and one of the onehotcoded columns.

X = X.drop(['Geography', 0], axis = 1)
X.head()
# Out:
#      1    2  CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0  0.0  0.0          619       0   42       2       0.00              1
# 1  0.0  1.0          608       0   41       1   83807.86              1
# 2  0.0  0.0          502       0   42       8  159660.80              3
# 3  0.0  0.0          699       0   39       1       0.00              2
# 4  0.0  1.0          850       0   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 0          1               1        101348.88
# 1          0               1        112542.58
# 2          1               0        113931.57
# 3          0               0         93826.63
# 4          1               1         79084.10

# %%
#train and test set split, and feature scaling

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#there is no rule on how many nodes each hidden layer should have
classifier = Sequential()

# %%
#init --> initialize weights according to uniform distribution
#input_dim is required for the first hidden layer, as it is the first starting point. --> number of nodes.
#output_dim --> number of nodes of the hidden layer
classifier.add(Dense(6, activation = 'relu', input_shape = (X_train.shape[1], )))
classifier.add(Dropout(rate=0.1))

# %%
classifier.add(Dense(6, activation = 'relu')) 
classifier.add(Dropout(rate=0.1))

# %%
# Adding the output layer
# Notice that we do not need to specify input dim. 
# we have an output of 1 node, which is the the desired dimensions of our output (stay with the bank or not)
# We use the sigmoid because we want probability outcomes
classifier.add(Dense(1, activation = 'sigmoid'))

# %%
classifier.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 6)                 72
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 6)                 0
# _________________________________________________________________
# dense_7 (Dense)              (None, 6)                 42
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 6)                 0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 121
# Trainable params: 121
# Non-trainable params: 0
# _________________________________________________________________

# %%
classifier.compile(optimizer='sgd', loss = 'binary_crossentropy', metrics=['accuracy'])

# %%
print(len(X_train))
print(len(Y_train))
# Out:
# 8000
# 8000

# %%
history = classifier.fit(X_train, Y_train,validation_data=(X_test, Y_test), epochs=100)
# Out:
# Train on 8000 samples, validate on 2000 samples
# Epoch 1/100
# 8000/8000 [==============================] - 0s 58us/step - loss: 0.5766 - accuracy: 0.7728 - val_loss: 0.5269 - val_accuracy: 0.7975
# Epoch 2/100
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.5252 - accuracy: 0.7960 - val_loss: 0.5095 - val_accuracy: 0.7975
# Epoch 3/100
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.5128 - accuracy: 0.7960 - val_loss: 0.5002 - val_accuracy: 0.7975
# Epoch 4/100
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.5028 - accuracy: 0.7960 - val_loss: 0.4936 - val_accuracy: 0.7975
# Epoch 5/100
# 8000/8000 [==============================] - 0s 50us/step - loss: 0.4986 - accuracy: 0.7960 - val_loss: 0.4881 - val_accuracy: 0.7975
# Epoch 6/100
# 8000/8000 [==============================] - 0s 39us/step - loss: 0.4929 - accuracy: 0.7960 - val_loss: 0.4833 - val_accuracy: 0.7975
# Epoch 7/100
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.4882 - accuracy: 0.7960 - val_loss: 0.4788 - val_accuracy: 0.7975
# Epoch 8/100
# 8000/8000 [==============================] - 0s 45us/step - loss: 0.4840 - accuracy: 0.7960 - val_loss: 0.4750 - val_accuracy: 0.7975
# Epoch 9/100
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.4808 - accuracy: 0.7960 - val_loss: 0.4711 - val_accuracy: 0.7975
# Epoch 10/100
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.4751 - accuracy: 0.7960 - val_loss: 0.4672 - val_accuracy: 0.7975
# Epoch 11/100
# 8000/8000 [==============================] - 0s 44us/step - loss: 0.4711 - accuracy: 0.7960 - val_loss: 0.4633 - val_accuracy: 0.7975
# Epoch 12/100
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.4703 - accuracy: 0.7960 - val_loss: 0.4598 - val_accuracy: 0.7975
# Epoch 13/100
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.4684 - accuracy: 0.7960 - val_loss: 0.4568 - val_accuracy: 0.7975
# Epoch 14/100
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.4627 - accuracy: 0.7960 - val_loss: 0.4536 - val_accuracy: 0.7975
# Epoch 15/100
# 8000/8000 [==============================] - 0s 52us/step - loss: 0.4583 - accuracy: 0.7960 - val_loss: 0.4507 - val_accuracy: 0.7975
# Epoch 16/100
# 8000/8000 [==============================] - 0s 39us/step - loss: 0.
100
# 8000/8000 [==============================] - 0s 42us/step - loss: 0.3949 - accuracy: 0.8420 - val_loss: 0.3733 - val_accuracy: 0.8585
# Epoch 77/100
# 8000/8000 [==============================] - ETA: 0s - loss: 0.4029 - accuracy: 0.83 - 0s 44us/step - loss: 0.4026 - accuracy: 0.8381 - val_loss: 0.3727 - val_accuracy: 0.8580
# Epoch 78/100
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.3966 - accuracy: 0.8384 - val_loss: 0.3719 - val_accuracy: 0.8585
# Epoch 79/100
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.4041 - accuracy: 0.8379 - val_loss: 0.3729 - val_accuracy: 0.8585
# Epoch 80/100
# 8000/8000 [==============================] - 0s 39us/step - loss: 0.4029 - accuracy: 0.8375 - val_loss: 0.3724 - val_accuracy: 0.8590
# Epoch 81/100
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.3982 - accuracy: 0.8378 - val_loss: 0.3713 - val_accuracy: 0.8625
# Epoch 82/100
# 8000/8000 [==============================] - 0s 47us/step - loss: 0.3984 - accuracy: 0.8401 - val_loss: 0.3713 - val_accuracy: 0.8600
# Epoch 83/100
# 8000/8000 [==============================] - 0s 42us/step - loss: 0.3976 - accuracy: 0.8403 - val_loss: 0.3700 - val_accuracy: 0.8615
# Epoch 84/100
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.3966 - accuracy: 0.8413 - val_loss: 0.3695 - val_accuracy: 0.8610
# Epoch 85/100
# 8000/8000 [==============================] - ETA: 0s - loss: 0.3938 - accuracy: 0.8460 ETA: 0s - loss: 0.4051 - accuracy - 0s 44us/step - loss: 0.3973 - accuracy: 0.8428 - val_loss: 0.3701 - val_accuracy: 0.8640
# Epoch 86/100
# 8000/8000 [==============================] - 0s 43us/step - loss: 0.3981 - accuracy: 0.8410 - val_loss: 0.3704 - val_accuracy: 0.8645
# Epoch 87/100
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.3910 - accuracy: 0.8413 - val_loss: 0.3676 - val_accuracy: 0.8615
# Epoch 88/100
# 8000/8000 [==============================] - 0s 39us/step - loss: 0.3982 - accuracy: 0.8379 - val_loss: 0.3688 - val_accuracy: 0.8645
# Epoch 89/100
# 8000/8000 [==============================] - 0s 42us/step - loss: 0.3953 - accuracy: 0.8413 - val_loss: 0.3687 - val_accuracy: 0.8650
# Epoch 90/100
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.3902 - accuracy: 0.8434 - val_loss: 0.3676 - val_accuracy: 0.8655
# Epoch 91/100
# 8000/8000 [==============================] - 0s 42us/step - loss: 0.3984 - accuracy: 0.8422 - val_loss: 0.3672 - val_accuracy: 0.8655
# Epoch 92/100
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.3930 - accuracy: 0.8431 - val_loss: 0.3663 - val_accuracy: 0.8660
# Epoch 93/100
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.3981 - accuracy: 0.8424 - val_loss: 0.3669 - val_accuracy: 0.8660
# Epoch 94/100
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.3946 - accuracy: 0.8443 - val_loss: 0.3658 - val_accuracy: 0.8640
# Epoch 95/100
# 8000/8000 [==============================] - 0s 39us/step - loss: 0.3963 - accuracy: 0.8419 - val_loss: 0.3657 - val_accuracy: 0.8625
# Epoch 96/100
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.3956 - accuracy: 0.8405 - val_loss: 0.3665 - val_accuracy: 0.8645
# Epoch 97/100
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.3919 - accuracy: 0.8415 - val_loss: 0.3655 - val_accuracy: 0.8635
# Epoch 98/100
# 8000/8000 [==============================] - 0s 39us/step - loss: 0.3938 - accuracy: 0.8421 - val_loss: 0.3668 - val_accuracy: 0.8635
# Epoch 99/100
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.3932 - accuracy: 0.8436 - val_loss: 0.3661 - val_accuracy: 0.8635
# Epoch 100/100
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.3920 - accuracy: 0.8385 - val_loss: 0.3651 - val_accuracy: 0.8635

# %%
y_pred = classifier.predict(X_test)
print(y_pred)
# Out:
# [[0.3421756 ]
#  [0.35379815]
#  [0.21799237]
#  ...
#  [0.290505  ]
#  [0.25709796]
#  [0.20978561]]

# %%
y_pred = (y_pred > 0.5).astype(int)
print(y_pred[:5])
# Out:
# [[0]
#  [0]
#  [0]
#  [0]
#  [0]]

# %%
from sklearn.metrics import confusion_matrix
confmat = confusion_matrix(Y_test, y_pred)
print(confmat)
# Out:
# [[1539   56]
#  [ 217  188]]

# %%
print (((confmat[0][0]+confmat[1][1])*100)/(confmat[0][0]+confmat[1][1]+confmat[0][1]+confmat[1][0]), '% of testing data was classified correctly')
# Out:
# 86.35 % of testing data was classified correctly
